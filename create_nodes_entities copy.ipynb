# %%
import pandas as pd
from gliner import GLiNER
import spacy
from tqdm.notebook import tqdm
import pickle

# %%
custom_spacy_config = { "gliner_model": "urchade/gliner_small-v2.1",
                            "chunk_size": 250,
                            "labels": ["people","company","organization","location","date","money"],
                            "style": "dep",
                            "threshold": 0.5,
                            "map_location": "mps"}
nlp = spacy.blank("en")
nlp.add_pipe("gliner_spacy", config=custom_spacy_config)
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# /Users/meghanapatakota/Library/Caches/pypoetry/virtualenvs/graph-ixHOddrH-py3.12/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /Users/meghanapatakota/Library/Caches/pypoetry/virtualenvs/graph-ixHOddrH-py3.12/lib/python3.12/site-packages/transformers/convert_slow_tokenizer.py:558: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
df = pd.read_csv('Global-Cases-Export-2024-09-25.csv')

df.columns = df.columns.str.lower().str.replace(' ', '_')
# split at jurisdictions to jurisdictions_country, jurisdictions_region, jurisdictions_type given the > separator. Eg: 'Australia>New South Wales>Land and Environment Court'
# Note: not all rows have all 3 values
df[['jurisdictions_country', 'jurisdictions_region', 'jurisdictions_type']] = df['jurisdictions'].str.split('>',n=2, expand=True)
df.head()
# Out:
#                                            case_name    id  \
# 0   Aldous v. Greater Taree City Council and Another  2204
# 1   Ground Crew at Turramurra v. Ku-ring-gai Council  2504
# 2  Haughton v. Minister for Department of Plannin...  2505
# 3  Able Lott Holdings Pty. Ltd. v. City of Fremantle  2508
# 4   Aldous v. Greater Taree City Council and Another  2510
#
#                                            permalink  \
# 0  https://climatecasechart.com/non-us-case/aldou...
# 1  https://climatecasechart.com/non-us-case/groun...
# 2  https://climatecasechart.com/non-us-case/haugh...
# 3  https://climatecasechart.com/non-us-case/able-...
# 4  https://climatecasechart.com/non-us-case/aldou...
#
#                                              summary  \
# 0  An Australian court upheld approval of a devel...
# 1  Applicant appealed the denial of a permit for ...
# 2  Ned Haughton challenged the approval granted b...
# 3  This case concerned a development application ...
# 4   An Australian court upheld approval of a deve...
#
#                                      case_categories  \
# 0  Suits against governments>Environmental assess...
# 1  Suits against governments>Environmental assess...
# 2  Suits against governments>Environmental assess...
# 3  Suits against governments>Environmental assess...
# 4                                                NaN
#
#                                        jurisdictions  \
# 0  Australia>New South Wales>Land and Environment...
# 1  Australia>New South Wales>Land and Environment...
# 2  Australia>New South Wales>Land and Environment...
# 3  Australia>Western Australia>State Administrati...
# 4  Australia>New South Wales>Land and Environment...
#
#                                       principal_laws                 status  \
# 0                                          Australia                    NaN
# 1  Australia>Environmental Planning and Assessmen...       Appeal dismissed
# 2  Australia>Precautionary Principle|Australia>Pr...  Application dismissed
# 3  Australia>State Coastal Planning Policy (Weste...  Application dismissed
# 4                                          Australia  Application dismissed
#
#                                        reporter_info  filing_year_for_action  \
# 0  Land and Environment Court of New South Wales ...                  2009.0
# 1                       [2008] NSWLEC 86 (Australia)                  2008.0
# 2                      [2011] NSWLEC 217 (Australia)                  2011.0
# 3                       [2010] WASAT 117 (Australia)                  2010.0
# 4                     [ 2009 ] NCWELC 17 (Australia)                  2009.0
#
#                                          core_object jurisdictions_country  \
# 0                                                NaN             Australia
# 1  Appeal of denial of a planning permit due to r...             Australia
# 2  Challenge to government approval of two coal-f...             Australia
# 3  Challenge to approve development of site despi...             Australia
# 4  Challenge to city council decision granting de...             Australia
#
#   jurisdictions_region             jurisdictions_type
# 0      New South Wales     Land and Environment Court
# 1      New South Wales     Land and Environment Court
# 2      New South Wales     Land and Environment Court
# 3    Western Australia  State Administrative Tribunal
# 4      New South Wales     Land and Environment Court

# %%
def split_text_to_chunks(text, chunk_size=250):
    return [text[i : i + chunk_size] for i in range(0, len(text), chunk_size)]


chunk_nodes = []
chunk_id = 1
for index, row in df.iterrows():
    text_chunks = split_text_to_chunks(row["summary"], 250)
    doc_id = row["id"]
    for chunk in text_chunks:
        chunk_nodes.append({"id": chunk_id, "doc_id": doc_id, "text": chunk})
        chunk_id += 1

# for chunk in chunk_nodes:
#     print(chunk)
chunk_nodes


def get_entities(text):
    doc = nlp(text)
    entities = []
    for ent in doc.ents:
        entities.append(
            {
                "text": ent.text,
                "start_char": ent.start_char,
                "end_char": ent.end_char,
                "label": ent.label_,
            }
        )
    return entities


entity_nodes = []
entity_id = 1
for chunk in tqdm(chunk_nodes):
    entities = get_entities(chunk["text"])
    for entity in entities:
        entity_nodes.append(
            {
                "id": entity_id,
                "chunk_id": chunk["id"],
                "text": entity["text"],
                "start_char": entity["start_char"],
                "end_char": entity["end_char"],
                "label": entity["label"],
            }
        )
# Out:
#   0%|          | 0/8694 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
# save the chunk and entities to pickle
pickle.dump(chunk_nodes, open("chunk_nodes.pkl", "wb"))
pickle.dump(entity_nodes, open("entity_nodes.pkl", "wb"))
