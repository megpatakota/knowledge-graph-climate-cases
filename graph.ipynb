# %%
import pickle

# %%
# load the pickled data
chunk_nodes = pickle.load(open("./graph_data/chunk_nodes.pkl", "rb"))
entity_nodes = pickle.load(open("./graph_data/entity_nodes.pkl", "rb"))
entity_nodes
# Out:
# [{'id': 1,
#   'chunk_id': 1,
#   'text': 'An Australian court',
#   'start_char': 0,
#   'end_char': 19,
#   'label': 'organization'},
#  {'id': 1,
#   'chunk_id': 1,
#   'text': 'city council',
#   'start_char': 70,
#   'end_char': 82,
#   'label': 'organization'},
#  {'id': 1,
#   'chunk_id': 1,
#   'text': 'beachfront property',
#   'start_char': 103,
#   'end_char': 122,
#   'label': 'location'},
#  {'id': 1,
#   'chunk_id': 2,
#   'text': 'The Council',
#   'start_char': 176,
#   'end_char': 187,
#   'label': 'organization'},
#  {'id': 1,
#   'chunk_id': 3,
#   'text': 'Council',
#   'start_char': 84,
#   'end_char': 91,
#   'label': 'organization'},
#  {'id': 1,
#   'chunk_id': 5,
#   'text': 'Applicant',
#   'start_char': 0,
#   'end_char': 9,
#   'label': 'organization'},
#  {'id': 1,
#   'chunk_id': 5,
#   'text': 'residential development',
#   'start_char': 48,
#   'end_char': 71,
#   'label': 'location'},
#  {'id': 1,
#   'chunk_id': 5,
#   'text': 'local council',
# ...
